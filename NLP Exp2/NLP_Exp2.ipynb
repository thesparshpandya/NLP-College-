# %% [markdown]
# <a href="https://colab.research.google.com/github/thesparshpandya/NLP-College-/blob/main/NLP_Exp2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nltk
import requests
from bs4 import BeautifulSoup
import matplotlib.pyplot as plt

# Download necessary NLTK datasets
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('omw-1.4')
nltk.download('averaged_perceptron_tagger')
nltk.download('averaged_perceptron_tagger_eng')
nltk.download('maxent_ne_chunker')
nltk.download('maxent_ne_chunker_tab')
nltk.download('words')
nltk.download('punkt_tab')

print("Setup Complete. Libraries Loaded.")
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package maxent_ne_chunker is already up-to-date!
# [nltk_data] Downloading package maxent_ne_chunker_tab to
# [nltk_data]     /root/nltk_data...
# Setup Complete. Libraries Loaded.
# [nltk_data]   Unzipping chunkers/maxent_ne_chunker_tab.zip.
# [nltk_data] Downloading package words to /root/nltk_data...
# [nltk_data]   Package words is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!

# %%
#URL to be scraped
url = "https://en.wikipedia.org/wiki/Lionel_Messi"

# Defining headers to mimic a real browser (This tells the server: "I am a Chrome browser, not a bot")
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36"
}

#Request to fetch the webpage content WITH HEADERS
response = requests.get(url, headers=headers)

#Check if the request was successful (Status Code 200)
if response.status_code == 200:
    print("Successfully fetched the webpage!")

    #Parse the HTML content
    soup = BeautifulSoup(response.content, 'html.parser')

    #Extract text from paragraph <p> tags only
    paragraphs = soup.find_all('p')
    text_data = " ".join([p.get_text() for p in paragraphs])
    print("\n--- Scraped Text Preview ---")
    print(text_data[:500])

else:
    print(f"Failed to retrieve the webpage. Status Code: {response.status_code}")
    text_data = ""
# Out:
# Successfully fetched the webpage!
#
# --- Scraped Text Preview ---
#
#
#  Lionel Andrés "Leo" Messi[note 1] (born 24 June 1987) is an Argentine professional footballer who plays as a forward for and captains both Major League Soccer club Inter Miami and the Argentina national team. Widely regarded as one of the greatest players in history, Messi has set numerous records for individual accolades won throughout his professional footballing career, including eight Ballon d'Ors, six European Golden Shoes, and eight times being named the world's best player by FIFA.[no

# %%
from nltk.tokenize import sent_tokenize, word_tokenize

# Tokenize sentences
sentences = sent_tokenize(text_data)
print("Sentence Count:", len(sentences))

# Tokenize words
words = word_tokenize(text_data)
print("Word Count:", len(words))
# Out:
# Sentence Count: 447
# Word Count: 14267

# %%
from nltk.corpus import stopwords
import string

stop_words = set(stopwords.words("english"))

# Remove stop words and punctuation
filtered_words = [w for w in words if w.lower() not in stop_words and w not in string.punctuation]

print("Filtered Word Count:", len(filtered_words))
# Out:
# Filtered Word Count: 7512

# %%
from nltk.stem import PorterStemmer, WordNetLemmatizer

ps = PorterStemmer()
lemmatizer = WordNetLemmatizer()

print(f"{'Word':<15} | {'Stemmed':<15} | {'Lemmatized':<15}")
print("-" * 50)

# Compare first 10 words
for w in filtered_words[:10]:
    print(f"{w:<15} | {ps.stem(w):<15} | {lemmatizer.lemmatize(w, pos='v'):<15}")
# Out:
# Word            | Stemmed         | Lemmatized
# --------------------------------------------------
# Lionel          | lionel          | Lionel
# Andrés          | andré           | Andrés
# ``              | ``              | ``
# Leo             | leo             | Leo
# ''              | ''              | ''
# Messi           | messi           | Messi
# note            | note            | note
# 1               | 1               | 1
# born            | born            | bear
# 24              | 24              | 24

# %%
from nltk import pos_tag, ne_chunk

# POS Tagging
pos_tags = pos_tag(filtered_words)
print("POS Tags Sample:", pos_tags[:5])

# Named Entity Recognition
ner_tree = ne_chunk(pos_tag(words))

print("\n--- Entities Detected ---")
for chunk in ner_tree:
    if hasattr(chunk, 'label'):
        print(chunk.label(), ' '.join(c[0] for c in chunk))
# Out:
# POS Tags Sample: [('Lionel', 'NNP'), ('Andrés', 'NNP'), ('``', '``'), ('Leo', 'NNP'), ("''", "''")]
#
# --- Entities Detected ---
# PERSON Lionel
# PERSON Andrés
# PERSON Messi
# PERSON League Soccer
# ORGANIZATION Inter Miami
# GPE Argentina
# PERSON Messi
# GPE Ballon
# ORGANIZATION European Golden Shoes
# ORGANIZATION FIFA
# ORGANIZATION All Time Men
# ORGANIZATION IFFHS
# PERSON Messi
# GPE Barcelona
# GPE La Liga
# ORGANIZATION FIFA
# ORGANIZATION Copa América
# PERSON Messi
# PERSON Messi
# PERSON Barcelona
# PERSON Barcelona
# GPE Spanish
# GPE Messi
# GPE Ballon
# GPE European
# PERSON Barcelona
# GPE La Liga
# PERSON Barcelona
# GPE Ballon
# PERSON Barcelona
# PERSON Ballon
# GPE Barcelona
# PERSON Messi
# ORGANIZATION UEFA
# ORGANIZATION Barcelona
# PERSON Messi
# GPE French
# PERSON Paris
# ORGANIZATION MLS
# ORGANIZATION Inter Miami
# ORGANIZATION MLS
# ORGANIZATION MVP
# ORGANIZATION Argentine
# PERSON Messi
# ORGANIZATION Summer Olympics
# GPE Argentina
# ORGANIZATION Copa América Centenario
# PERSON Messi
# GPE Argentina
# GPE Ballon
# GPE Argentina
# GPE Ballon
# PERSON Messi
# PERSON Messi
# PERSON Adidas
# GPE France Football
# ORGANIZATION Forbes
# PERSON Messi
# PERSON Time
# ORGANIZATION Laureus
# PERSON Messi
# GPE Ballon
# PERSON Dream Team
# GSP US
# PERSON Messi
# PERSON Time
# ORGANIZATION Athlete
# GPE Freedom
# GPE US
# PERSON Joe Biden
# PERSON Messi
# GPE Rosario
# PERSON Santa Fe Province
# PERSON Jorge Messi
# ORGANIZATION Acindar
# GPE Villa Constitución
# PERSON Celia Cuccittini
# GPE Rosario
# PERSON Las Heras
# PERSON Messi
# PERSON Jorge Messi
# ORGANIZATION Argentine Armed
# PERSON Messi
# GPE Italian
# GPE Spanish
# ORGANIZATION Adriatic Marche
# GPE Italy
# PERSON Porto Recanati
# GPE Italian
# PERSON Rodrigo
# PERSON Matías
# GPE Maximiliano
# PERSON Emanuel Biancucchi
# PERSON Abanderado Grandoli FC
# GPE Celia
# ORGANIZATION Catholic
# PERSON Messi
# ORGANIZATION Newell
# ORGANIZATION Old Boys
# ORGANIZATION Newell
# ORGANIZATION Machine
# PERSON Messi
# ORGANIZATION Newell
# GPE Brazilian
# PERSON Ronaldo
# PERSON Messi
# PERSON Messi
# ORGANIZATION Newell
# PERSON Messi
# ORGANIZATION Buenos Aires
# PERSON River Plate
# PERSON Messi
# GPE Argentina
# ORGANIZATION FIFA
# GPE Greece
# PERSON Messi
# GPE Argentina
# GPE Germany
# PERSON Messi
# GPE Argentina
# GPE Messi
# PERSON Messi
# GPE Uruguay
# PERSON Messi
# PERSON Messi
# GPE Argentina
# ORGANIZATION FIFA
# PERSON Messi
# GPE Argentina
# GPE Germany
# PERSON Messi
# ORGANIZATION Golden Ball
# PERSON Argentina
# GSP Chile
# PERSON Messi
# ORGANIZATION Golden Ball
# PERSON América Centenario
# GPE United States
# PERSON Messi
# PERSON Gabriel Batistuta
# GPE Argentina
# GPE Argentina
# GSP Chile
# PERSON Messi
# PERSON Messi
# GPE Argentina
# ORGANIZATION FIFA
# PERSON Argentina
# GPE Ecuador
# PERSON Messi
# GPE France
# PERSON Messi
# PERSON Messi
# GPE Argentina
# PERSON Brazil
# GPE Chile
# GPE Argentina
# GPE Argentina
# GPE Bolivia
# PERSON Javier Mascherano
# GPE Argentina
# GPE Argentina
# PERSON Brazil
# PERSON Messi
# GPE Argentina
# GPE Argentina
# ORGANIZATION UEFA
# GPE Italy
# ORGANIZATION FIFA
# PERSON Messi
# GPE Argentina
# GPE France
# PERSON Messi
# ORGANIZATION Golden Ball
# PERSON Curaçao
# PERSON Messi
# LOCATION South
# GPE American
# PERSON Peru
# GPE Messi
# ORGANIZATION CONMEBOL
# GPE Canada
# PERSON Messi
# GPE Colombia
# PERSON Messi
# ORGANIZATION Copa América
# GPE Venezuela
# PERSON Iván Hurtado
# ORGANIZATION CONMEBOL
# GPE Puerto Rico
# PERSON Due
# PERSON Messi
# GPE Spanish
# ORGANIZATION Atomic Flea
# GPE Barcelona
# PERSON Pep Guardiola
# PERSON Messi
# PERSON Messi
# PERSON Messi
# PERSON Messi
# PERSON Messi
# GPE Argentina
# PERSON Diego Maradona
# PERSON Messi
# GPE Barcelona
# PERSON Xavi
# PERSON Andrés Iniesta
# PERSON Messi
# PERSON Messi
# GPE Argentine
# GPE Spain
# PERSON Frank Rijkaard
# PERSON Guardiola
# PERSON Messi
# PERSON Xavi
# PERSON Iniesta
# PERSON Luis Enrique
# PERSON Messi
# PERSON Ernesto Valverde
# PERSON Messi
# PERSON Luis Suárez
# GPE Argentina
# PERSON Messi
# GPE Portuguese
# PERSON Cristiano Ronaldo
# ORGANIZATION All Time Men
# ORGANIZATION IFFHS
# PERSON Messi
# PERSON Ronaldinho
# GPE Ballon
# ORGANIZATION Barça
# PERSON Messi
# GPE Ballon
# PERSON Pep Guardiola
# PERSON Messi
# PERSON Barça
# GPE Messi
# GPE Europe
# PERSON Messi
# GPE Argentina
# ORGANIZATION FIFA
# PERSON Messi
# PERSON Messi
# PERSON Cristiano Ronaldo
# PERSON Messi
# ORGANIZATION Muhammad
# PERSON Ronaldo
# PERSON Ronaldo
# PERSON Messi
# PERSON Ronaldo
# PERSON Messi
# PERSON Messi
# PERSON Ronaldo
# ORGANIZATION FIFA World
# PERSON Ronaldo
# ORGANIZATION European Golden
# PERSON Ronaldo
# PERSON Ronaldo
# PERSON Messi
# PERSON Ronaldo
# PERSON Ronaldo
# PERSON Messi
# GPE Barcelona
# ORGANIZATION UEFA
# PERSON Ronaldo
# PERSON Manchester United
# PERSON Messi
# GPE Barcelona
# PERSON Ronaldo
# ORGANIZATION Real Madrid
# GPE Barcelona
# PERSON Messi
# PERSON Ronaldo
# GPE El Clásico
# PERSON Ronaldo
# GPE Juventus
# ORGANIZATION UEFA
# PERSON Ronaldo
# PERSON Juventus
# PERSON Messi
# GPE Barcelona
# PERSON Ronaldo
# ORGANIZATION Real Madrid
# PERSON Juventus
# PERSON Messi
# PERSON Cristiano
# PERSON La Liga
# PERSON Messi
# GPE Argentina
# PERSON Messi
# PERSON Messi
# GPE Argentinian
# PERSON Messi
# PERSON Messi
# PERSON Diego Maradona
# GPE Argentina
# PERSON Messi
# ORGANIZATION Argentine
# GPE New Maradona
# PERSON Messi
# PERSON Argentina
# PERSON Maradona
# PERSON Messi
# PERSON Maradona
# PERSON Maradona
# GPE Argentina
# ORGANIZATION FIFA
# PERSON Messi
# GPE Argentina
# PERSON Maradona
# PERSON Maradona
# PERSON Messi
# PERSON Messi
# PERSON Maradona
# GPE Argentine
# PERSON Messi
# PERSON Maradona
# GPE Argentina
# ORGANIZATION FIFA
# PERSON Messi
# GPE Maradona
# PERSON Messi
# ORGANIZATION Argentine Primera División
# GPE La
# PERSON Argentines
# GPE Rosario
# PERSON Maradona
# PERSON Messi
# GPE Furthermore
# PERSON Messi
# ORGANIZATION Albiceleste
# PERSON Catalan
# PERSON Argentine
# GPE Barcelona
# PERSON Messi
# GPE Spain
# GPE Argentina
# ORGANIZATION Football
# PERSON Tim Vickery
# GPE Messi
# ORGANIZATION Argentines
# PERSON Messi
# PERSON Messi
# GPE Barcelona
# PERSON Messi
# GPE Argentina
# PERSON Vickery
# PERSON Messi
# PERSON Maradona
# PERSON Jorge Valdano
# PERSON Messi
# PERSON Osvaldo Ardiles
# PERSON Messi
# GPE Netherlands
# GPE Maradona
# PERSON Messi
# GPE Argentina
# ORGANIZATION Argentines
# PERSON Messi
# PERSON Messi
# PERSON Cristiano Ronaldo
# PERSON Photo
# ORGANIZATION Final
# GPE Messi
# GPE Argentina
# GPE Germany
# PERSON Terry Gibson
# GPE Facebook
# PERSON Messi
# PERSON Ronaldo
# PERSON Ronaldo
# PERSON Buenos Aires
# PERSON Messi
# PERSON Messi
# PERSON Messi
# PERSON Messi
# GPE Kerala
# GPE India
# GPE Messi
# ORGANIZATION Kudamattam
# PERSON Messi
# ORGANIZATION Inter Miami
# GPE Hong Kong
# GPE Hong Kong Stadium
# PERSON Messi
# GPE Hong Kong
# GPE China
# GPE Chinese
# GPE Furthermore
# GPE Chinese
# ORGANIZATION Argentine Football Association
# PERSON Messi
# PERSON Messi
# ORGANIZATION Forbes
# PERSON Cristiano Ronaldo
# PERSON Barcelona
# PERSON Barcelona
# PERSON Messi
# PERSON Ronaldo
# ORGANIZATION Inter Miami
# PERSON Messi
# ORGANIZATION MLS Season Pass
# GPE Messi
# ORGANIZATION SportsPro
# PERSON Adidas
# PERSON Barcelona
# PERSON Nike
# GPE Adidas
# PERSON Messi
# PERSON Adidas F50
# GPE Adidas
# ORGANIZATION Adidas Messi
# ORGANIZATION Adidas Nemeziz
# GPE Barcelona
# PERSON Messi
# PERSON Adidas
# PERSON Messi
# GPE Argentina
# PERSON Messi
# PERSON Ronaldo
# PERSON David Beckham
# GPE Adidas
# PERSON Pepsi
# GPE Konami
# PERSON Gabbana
# PERSON Audemars Piguet
# PERSON Gillette
# GPE Turkish Airlines
# PERSON Ooredoo
# PERSON Tata Motors
# PERSON Barcelona
# PERSON Budweiser
# PERSON Messi
# PERSON Messi
# GPE Konami
# ORGANIZATION PES
# ORGANIZATION PES
# ORGANIZATION PES
# ORGANIZATION PES
# ORGANIZATION EA Sports
# ORGANIZATION FIFA
# ORGANIZATION FIFA
# ORGANIZATION FIFA
# GPE Turkish Airlines
# PERSON Messi
# PERSON Kobe Bryant
# ORGANIZATION YouTube
# ORGANIZATION YouTube
# PERSON Messi
# ORGANIZATION Hard Rock Cafe
# PERSON Messi
# GPE Saudi Arabia
# PERSON Due
# GPE Saudi Arabia
# PERSON Messi
# GPE Saudi
# PERSON Messi
# ORGANIZATION United Nations Children
# ORGANIZATION UNICEF
# PERSON Barcelona
# ORGANIZATION UNICEF Goodwill Ambassador
# GPE Haiti
# ORGANIZATION UNICEF
# ORGANIZATION HIV
# PERSON Messi
# PERSON Thiago
# ORGANIZATION UNICEF
# PERSON Messi
# ORGANIZATION Leo Messi Foundation
# PERSON Messi
# GPE Boston
# PERSON Messi
# GPE Argentina
# GPE Spain
# PERSON Messi
# PERSON Adidas
# GPE Japan
# PERSON Messi
# GPE Argentina
# PERSON Sarmiento
# ORGANIZATION Rosario
# ORGANIZATION Newell
# ORGANIZATION Old Boys
# PERSON Rosario Central
# FACILITY River Plate
# PERSON Boca Juniors
# GSP Buenos Aires
# ORGANIZATION Newell
# ORGANIZATION Old Boys
# ORGANIZATION Newell
# PERSON Ernesto Vecchio
# ORGANIZATION Leo Messi Foundation
# PERSON Messi
# PERSON La Razón
# PERSON Médecins Sans Frontières
# PERSON Messi
# PERSON Clinic Barcelona
# GPE Barcelona
# GPE Argentina
# PERSON Messi
# ORGANIZATION FC Barcelona
# ORGANIZATION Argentine Football
# ORGANIZATION FIFA
# PERSON Messi
# PERSON Messi
# ORGANIZATION Museu Nacional
# GPE Adidas
# PERSON Barcelona
# PERSON Pelé
# PERSON Messi
# GPE Chinese
# PERSON Sinovac Biotech
# PERSON Messi
# GPE Sinovac
# ORGANIZATION CoronaVac
# GPE South America
# PERSON Uruguay
# PERSON Luis Lacalle Pou
# PERSON Canelones Yamandú Orsi
# ORGANIZATION CONMEBOL
# ORGANIZATION Copa América
# ORGANIZATION Canelones
# PERSON Messi
# GPE Freedom
# GPE United States
# PERSON Joe Biden
# PERSON Biden
# PERSON Messi
# ORGANIZATION Sistine
# GPE Football
# PERSON Michelangelo
# ORGANIZATION Creation
# PERSON Adam
# PERSON Diego Maradona
# ORGANIZATION Sportivo Pereyra
# GPE Barracas
# GSP Buenos Aires
# PERSON Messi
# PERSON Madame Tussauds
# GPE Messi
# FACILITY Wembley Stadium
# PERSON Messi
# GSP Buenos
# GPE Messi
# ORGANIZATION CONMEBOL
# GPE Luque
# GPE Paraguay
# GPE Argentina
# GPE Pelé
# PERSON Maradona
# PERSON Messi
# GPE India
# PERSON Messi
# ORGANIZATION Sree Bhumi
# GPE Lake Town
# PERSON Kolkata
# PERSON Messi
# ORGANIZATION FIFA
# PERSON Messi
# PERSON Álex
# GPE Iglesia
# ORGANIZATION Venice International Film Festival
# PERSON Messi
# ORGANIZATION Rise
# GPE Legend
# PERSON Messi
# GPE Argentina
# ORGANIZATION FIFA
# PERSON Apple TV+
# PERSON Messi
# GPE American
# PERSON Messi
# GPE Miami
# GPE Florida
# GPE Publix
# GPE Walmart
# GPE Gopuff
# GPE South
# FACILITY White Claw Hard Seltzer
# PERSON Mark Anthony
# PERSON Messi
# PERSON Rosario
# GPE Miami
# GPE Los Angeles
# PERSON Smuggler Entertainment
# PERSON Messi
# ORGANIZATION Rise
# PERSON Messi
# PERSON Luis Suárez
# PERSON Deportivo LSM
# PERSON Messi
# PERSON Antonela Roccuzzo
# GPE Rosario
# PERSON Roccuzzo
# PERSON Lucas Scaglia
# PERSON Messi
# GPE Sitges
# GPE Roccuzzo
# PERSON Messi
# GPE Argentina
# PERSON Ecuador
# PERSON Thiago
# GPE Barcelona
# PERSON Messi
# ORGANIZATION Catholic
# GPE Celia
# PERSON Jorge
# PERSON Rodrigo
# PERSON Matías
# ORGANIZATION Leo Messi Foundation
# GPE Rosario
# PERSON Spain
# PERSON Messi
# GPE Rosario
# GSP Buenos Aires
# PERSON Rosario
# PERSON Buenos Aires
# PERSON Messi
# GPE Rosario
# ORGANIZATION Machine
# ORGANIZATION Newell
# ORGANIZATION Old Boys
# GPE Barcelona
# ORGANIZATION Newell
# PERSON Messi
# PERSON Rosario
# ORGANIZATION Newell
# GPE Argentina
# GPE Italy
# GPE Spain
# PERSON Messi
# PERSON Uruguay
# PERSON Belize
# GPE Panama
# ORGANIZATION Messis
# ORGANIZATION Panama Papers
# PERSON Messi
# PERSON Messi
# PERSON Barcelona
# PERSON Paris
# PERSON Argentina U20
# PERSON Argentina U23
# PERSON Argentina

# %%
from nltk.corpus import wordnet

# Lookup definition
term = "football"
syns = wordnet.synsets(term)

if syns:
    print(f"Def ({term}):", syns[0].definition())
# Out:
# Def (football): any of various games played with a ball (round or oval) in which two teams try to kick or carry or propel the ball into each other's goal
